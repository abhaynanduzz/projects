# %%
train_path='C:\\Nanduzz\\sTudY\\Csv files\\CAstron\\IMG\\train'
validation_path='C:\\Nanduzz\\sTudY\\Csv files\\CAstron\\IMG\\test'

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
#base model
train_datagen=ImageDataGenerator(rescale=1./255)
test_datagen=ImageDataGenerator(rescale=1./255)

# %%
#generating the train data
training_set=train_datagen.flow_from_directory(train_path,target_size=(64,64),batch_size=18,class_mode='categorical')
# Out:
# Found 158 images belonging to 21 classes.

# %%
#Generating the validation Data
validation_set=test_datagen.flow_from_directory(validation_path,target_size=(64,64),batch_size=18,class_mode='categorical')
# Out:
# Found 42 images belonging to 21 classes.

# %%
from keras.models import Sequential
from keras.layers import Convolution2D
from keras.layers import MaxPool2D
from keras.layers import Flatten
from keras.layers import Dense

# %%
classifier=Sequential()

# %%
classifier.add(Convolution2D(32,kernel_size=(3,3),input_shape=(64,64,3),activation='relu'))
classifier.add(MaxPool2D(pool_size=(2,2)))
classifier.add(Convolution2D(64,kernel_size=(3,3),activation='relu'))
classifier.add(MaxPool2D(pool_size=(2,2)))
classifier.add(Convolution2D(64,kernel_size=(3,3),activation='relu'))
classifier.add(Flatten())
classifier.add(Dense(64,activation='relu'))
classifier.add(Dense(21,activation='softmax'))

# %%
classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 62, 62, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 31, 31, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 29, 29, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 12, 12, 64)        36928
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 64)                589888
#
#  dense_1 (Dense)             (None, 21)                1365
#
# ...
# Total params: 647,573
# Trainable params: 647,573
# Non-trainable params: 0
# _________________________________________________________________

# %%
classifier.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
history=classifier.fit(training_set,epochs=20,validation_data=validation_set)
# Out:
# Epoch 1/20
# 9/9 [==============================] - 6s 660ms/step - loss: 3.0759 - accuracy: 0.0253 - val_loss: 3.0209 - val_accuracy: 0.0476
# Epoch 2/20
# 9/9 [==============================] - 5s 545ms/step - loss: 2.9712 - accuracy: 0.1392 - val_loss: 2.9169 - val_accuracy: 0.1429
# Epoch 3/20
# 9/9 [==============================] - 5s 547ms/step - loss: 2.6722 - accuracy: 0.2278 - val_loss: 2.6427 - val_accuracy: 0.3095
# Epoch 4/20
# 9/9 [==============================] - 5s 592ms/step - loss: 2.0138 - accuracy: 0.3861 - val_loss: 2.3602 - val_accuracy: 0.3810
# Epoch 5/20
# 9/9 [==============================] - 5s 567ms/step - loss: 1.3366 - accuracy: 0.6139 - val_loss: 2.4753 - val_accuracy: 0.4286
# Epoch 6/20
# 9/9 [==============================] - 5s 558ms/step - loss: 0.8589 - accuracy: 0.7658 - val_loss: 2.2593 - val_accuracy: 0.5714
# Epoch 7/20
# ...

# %%
import matplotlib.pyplot as plt
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']
epochs=range(1,len(acc)+1)
plt.plot(epochs,acc,'bo',label='training_acc')
plt.plot(epochs,val_acc,'r',label='validation acc')
plt.title('Training and Validation')
plt.legend()
plt.figure()

# %%
plt.plot(epochs,loss,'bo',label='training_loss')
plt.plot(epochs,val_loss,'r',label='validation loss')
plt.title('Training and Validation loss')
plt.legend()
plt.figure()
plt.show()

# %% [markdown]
# ## Model2`

# %%
#adding parameters
train_datagen=ImageDataGenerator(rescale=1./255,shear_range=0.5,zoom_range=0.5,width_shift_range=0.2)
test_datagen=ImageDataGenerator(rescale=1./255)

# %%
training_set=train_datagen.flow_from_directory(train_path,target_size=(64,64),batch_size=10,class_mode='categorical')
# Out:
# Found 158 images belonging to 21 classes.

# %%
validation_set=test_datagen.flow_from_directory(validation_path,target_size=(64,64),batch_size=10,class_mode='categorical')
# Out:
# Found 42 images belonging to 21 classes.

# %%
classifier=Sequential()

# %%
classifier.add(Convolution2D(32,kernel_size=(3,3),input_shape=(64,64,3),activation='relu'))
classifier.add(MaxPool2D(pool_size=(2,2)))
classifier.add(Convolution2D(64,kernel_size=(3,3),activation='relu'))
classifier.add(MaxPool2D(pool_size=(2,2)))
classifier.add(Convolution2D(64,kernel_size=(3,3),activation='relu'))
classifier.add(Flatten())
classifier.add(Dense(64,activation='relu'))
classifier.add(Dense(21,activation='softmax'))

# %%
classifier.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_3 (Conv2D)           (None, 62, 62, 32)        896
#
#  max_pooling2d_2 (MaxPooling  (None, 31, 31, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 29, 29, 64)        18496
#
#  max_pooling2d_3 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 12, 12, 64)        36928
#
#  flatten_1 (Flatten)         (None, 9216)              0
#
#  dense_2 (Dense)             (None, 64)                589888
#
#  dense_3 (Dense)             (None, 21)                1365
#
# ...
# Total params: 647,573
# Trainable params: 647,573
# Non-trainable params: 0
# _________________________________________________________________

# %%
classifier.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
history=classifier.fit_generator(training_set,epochs=71,validation_data=validation_set)
# Out:
# C:\Users\abhay\AppData\Local\Temp\ipykernel_23108\774669007.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history=classifier.fit_generator(training_set,epochs=71,validation_data=validation_set)
# Epoch 1/71
# 16/16 [==============================] - 7s 385ms/step - loss: 3.0731 - accuracy: 0.0253 - val_loss: 3.0439 - val_accuracy: 0.0476
# Epoch 2/71
# 16/16 [==============================] - 6s 373ms/step - loss: 3.0437 - accuracy: 0.0886 - val_loss: 3.0355 - val_accuracy: 0.0476
# Epoch 3/71
# 16/16 [==============================] - 5s 331ms/step - loss: 3.0201 - accuracy: 0.0886 - val_loss: 3.0030 - val_accuracy: 0.0952
# Epoch 4/71
# 16/16 [==============================] - 5s 315ms/step - loss: 2.8926 - accuracy: 0.1456 - val_loss: 3.1358 - val_accuracy: 0.0476
# Epoch 5/71
# ...

# %%
import matplotlib.pyplot as plt
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']
epochs=range(1,len(acc)+1)
plt.plot(epochs,acc,'bo',label='training_acc')
plt.plot(epochs,val_acc,'g',label='validation acc')
plt.title('Training and Validation')
plt.legend()
plt.figure()

# %%
plt.plot(epochs,loss,'bo',label='training_loss')
plt.plot(epochs,val_loss,'g',label='validation loss')
plt.title('Training and Validation loss')
plt.legend()
plt.figure()
plt.show()

# %% [markdown]
# # val_accuracy: 0.6905
